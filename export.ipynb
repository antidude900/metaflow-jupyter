# %%
# !pip install "metaflow-jupyter[widgets] @ git+https://github.com/antidude900/metaflow-jupyter.git" --quiet

# %%
# %load_ext metaflow_jupyter

# %%
import os
os.environ['USERNAME'] = 'ColabUser'

# %% [markdown]
# # Flow 1

# %%
# %%mf_step start
# print("Start step of MyFlow")

# %%
# %%mf_step end
# print("End step of MyFlow")

# %% [markdown]
# # Flow 2

# %%
# %%mf_step Flow2.start
# print("Start step of Flow 2")

# %%
# %%mf_step Flow2.end
# print("End step of Flow 2")

# %% [markdown]
# # Flow 3

# %%
# %%mf_step Flow3.start
# print("Start step of Flow 3")

# %%
# %%mf_step Flow3.end
# print("End step of Flow 3")
