# %% [markdown]
# # DagWidget Demo

# %%
from metaflow import FlowSpec, step
from metaflow_jupyter import DagWidget

# %% [markdown]
# ## 1. Static view — Simple

# %%
class ForeachDemoFlow(FlowSpec):
    @step
    def start(self):
        self.next(self.branch_a, self.branch_b)

    @step
    def branch_a(self):
        self.next(self.branch_f)
    
    @step
    def branch_b(self):
        self.items = [str(x) for x in range(5)]
        self.next(self.branch_c,foreach="items")
    @step
    def branch_c(self):
        self.next(self.branch_d,self.branch_e)
    @step
    def branch_d(self):
        self.next(self.join)
    @step
    def branch_e(self):
        self.next(self.join)
    @step
    def branch_f(self):
        self.next(self.join)
    @step
    def join(self, inputs):
        items = [1,2,3]
        self.next(self.end)

    @step
    def end(self):
        print("Done:", self.results)

DagWidget(ForeachDemoFlow)

# %% [markdown]
# ## 2. Static view - Overflow Horizontal

# %%
from metaflow import FlowSpec, step, NBRunner
from metaflow_jupyter import DagWidget
class BranchFlow(FlowSpec):
    @step
    def start(self):
        self.next(self.branch_a, self.branch_b, self.branch_c)

    @step
    def branch_a(self):
        self.result = "A"
        self.next(self.join)

    @step
    def branch_b(self):
        self.result = "B"
        self.next(self.join)
    @step
    def branch_c(self):
        self.result = "C"
        self.next(self.join)

    @step
    def join(self, inputs):
        self.results = [i.result for i in inputs]
        self.next(self.linear1)

    @step
    def linear1(self):
        self.next(self.linear2)
    @step
    def linear2(self):
        self.next(self.linear3)
    @step
    def linear3(self):
        self.next(self.linear4)
    @step
    def linear4(self):
        self.next(self.linear5)
    @step
    def linear5(self):
        self.next(self.linear6)
    @step
    def linear6(self):
        self.next(self.linear7)
    @step
    def linear7(self):
        self.next(self.end)

    @step
    def end(self):
        print(self.results)

DagWidget(BranchFlow)

# %% [markdown]
# ## 3. Static View - Overflow Vertical

# %%
from metaflow import FlowSpec, step, NBRunner
from metaflow_jupyter import DagWidget
class BranchFlow(FlowSpec):
    @step
    def start(self):
        self.next(self.branch1,self.branch2,self.branch3,self.branch4,self.branch5,self.branch6,self.branch7,self.branch8,self.branch9,self.branch10,self.branch11,self.branch12,self.branch13,self.branch14,self.branch15)

    @step
    def branch1(self):
        self.next(self.join)
    @step
    def branch2(self):
        self.next(self.join)
    @step
    def branch3(self):
        self.next(self.join)
    @step
    def branch4(self):
        self.next(self.join)
    @step
    def branch5(self):
        self.next(self.join)
    @step
    def branch6(self):
        self.next(self.join)
    @step    
    def branch7(self):
        self.next(self.join)
    @step
    def branch8(self):
        self.next(self.join)
    @step
    def branch9(self):
        self.next(self.join)
    @step
    def branch10(self):
        self.next(self.join)
    @step
    def branch11(self):
        self.next(self.join)
    @step
    def branch12(self):
        self.next(self.join)
    @step
    def branch13(self):
        self.next(self.join)
    @step
    def branch14(self):
        self.next(self.join)
    @step
    def branch15(self):
        self.next(self.join)
    @step
    def join(self, inputs):
        self.results = [i.result for i in inputs]
        self.next(self.end)

    @step
    def end(self):
        print(self.results)

DagWidget(BranchFlow)

# %% [markdown]
# ## 3. Live View

# %%
from metaflow import FlowSpec, step
import time
from metaflow_jupyter import DagWidget

#Short Ones
class ForeachUXFlow(FlowSpec):
    @step
    def start(self):
        self.items = ["a"] # dynamic value (cant decode this value from AST)
        self.next(self.analyze,foreach="items")

    @step
    def analyze(self):
        self.next(self.join)
    
    @step
    def join(self,inputs):
        self.next(self.start2)

    @step
    def start2(self):
        self.items = ["ABCDEFGHIJKLMNOPQRSTUVWXYZ","a","b","c","d","e"] 
        self.next(self.analyze2,foreach="items")

    @step
    def analyze2(self):
        self.next(self.join2)
    
    @step
    def join2(self,inputs):
        self.next(self.end)

    @step
    def end(self):
        pass 


DagWidget(ForeachUXFlow,run=True)
# Out:
# 2026-03-05 10:08:16.457 Workflow starting (run-id 1772705296454076):
# 2026-03-05 10:08:16.559 [1772705296454076/start/1 (pid 2678)] Task is starting.
# 2026-03-05 10:08:18.211 [1772705296454076/start/1 (pid 2678)] Foreach yields 1 child steps.
# 2026-03-05 10:08:18.211 [1772705296454076/start/1 (pid 2678)] Task finished successfully.
# 2026-03-05 10:08:18.223 [1772705296454076/analyze/2 (pid 2686)] Task is starting.
# 2026-03-05 10:08:19.746 [1772705296454076/analyze/2 (pid 2686)] Task finished successfully.
# 2026-03-05 10:08:19.759 [1772705296454076/join/3 (pid 2699)] Task is starting.
# 2026-03-05 10:08:21.320 [1772705296454076/join/3 (pid 2699)] Task finished successfully.
# 2026-03-05 10:08:21.338 [1772705296454076/start2/4 (pid 2708)] Task is starting.
# 2026-03-05 10:08:22.779 [1772705296454076/start2/4 (pid 2708)] Foreach yields 6 child steps.
# 2026-03-05 10:08:22.779 [1772705296454076/start2/4 (pid 2708)] Task finished successfully.
# 2026-03-05 10:08:22.794 [1772705296454076/analyze2/5 (pid 2720)] Task is starting.
# 2026-03-05 10:08:22.808 [1772705296454076/analyze2/6 (pid 2721)] Task is starting.
# 2026-03-05 10:08:22.819 [1772705296454076/analyze2/7 (pid 2722)] Task is starting.
# 2026-03-05 10:08:22.840 [1772705296454076/analyze2/8 (pid 2723)] Task is starting.
# 2026-03-05 10:08:22.846 [1772705296454076/analyze2/9 (pid 2724)] Task is starting.
# 2026-03-05 10:08:22.861 [1772705296454076/analyze2/10 (pid 2725)] Task is starting.
# 2026-03-05 10:08:28.685 [1772705296454076/analyze2/6 (pid 2721)] Task finished successfully.
# 2026-03-05 10:08:28.702 [1772705296454076/analyze2/5 (pid 2720)] Task finished successfully.
# 2026-03-05 10:08:28.704 [1772705296454076/analyze2/8 (pid 2723)] Task finished successfully.
# 2026-03-05 10:08:28.745 [1772705296454076/analyze2/9 (pid 2724)] Task finished successfully.
# 2026-03-05 10:08:28.789 [1772705296454076/analyze2/10 (pid 2725)] Task finished successfully.
# 2026-03-05 10:08:28.793 [1772705296454076/analyze2/7 (pid 2722)] Task finished successfully.
# 2026-03-05 10:08:28.844 [1772705296454076/join2/11 (pid 2762)] Task is starting.
# 2026-03-05 10:08:30.717 [1772705296454076/join2/11 (pid 2762)] Task finished successfully.
# 2026-03-05 10:08:30.735 [1772705296454076/end/12 (pid 2773)] Task is starting.
# 2026-03-05 10:08:32.302 [1772705296454076/end/12 (pid 2773)] Task finished successfully.
# 2026-03-05 10:08:32.308 Done!

# %%
from metaflow import FlowSpec, step
import time
from metaflow_jupyter import DagWidget

#Short Ones
class ForeachUXFlow(FlowSpec):
    @step
    def start(self):
        self.next(self.a,self.b)

    @step
    def a(self):
        self.next(self.join)
    
    @step
    def b(self):
        import time
        time.sleep(3)
        self.next(self.join)

    @step
    def join(self,inputs):
        self.next(self.end)

    @step 
    def end(self):
        pass

DagWidget(ForeachUXFlow,run=True)
# Out:
# 2026-03-03 15:36:28.400 Workflow starting (run-id 1772552188396145):
# 2026-03-03 15:36:28.464 [1772552188396145/start/1 (pid 93053)] Task is starting.
# 2026-03-03 15:36:29.674 [1772552188396145/start/1 (pid 93053)] Task finished successfully.
# 2026-03-03 15:36:29.686 [1772552188396145/a/2 (pid 93065)] Task is starting.
# 2026-03-03 15:36:29.695 [1772552188396145/b/3 (pid 93066)] Task is starting.
# 2026-03-03 15:36:30.755 [1772552188396145/a/2 (pid 93065)] Task finished successfully.
# 2026-03-03 15:36:33.768 [1772552188396145/b/3 (pid 93066)] Task finished successfully.
# 2026-03-03 15:36:33.776 [1772552188396145/join/4 (pid 93085)] Task is starting.
# 2026-03-03 15:36:34.590 [1772552188396145/join/4 (pid 93085)] Task finished successfully.
# 2026-03-03 15:36:34.597 [1772552188396145/end/5 (pid 93103)] Task is starting.
# 2026-03-03 15:36:35.489 [1772552188396145/end/5 (pid 93103)] Task finished successfully.
# 2026-03-03 15:36:35.489 Done!
